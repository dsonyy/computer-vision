# %% [markdown]
# # Haar feature-based cascade faces classification

# %%
from PIL import Image
from IPython.display import display
import numpy as np
import cv2 as cv

# %%
face_cascade = cv.CascadeClassifier("haarcascade_frontalface_default.xml")

for filename in ["lena.bmp", "elon.png", "faces.png"]:
    img = cv.imread(filename)
    gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

    faces = face_cascade.detectMultiScale(gray, 1.2, 4)
    for (x, y, w, h) in faces:
        cv.rectangle(img, (x, y), (x + w, y + h), (255, 255, 0), 2)

    img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
    display(Image.fromarray(img))
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x1A8D7FBE688>
# <PIL.Image.Image image mode=RGB size=722x438 at 0x1A8D7FDB848>
# <PIL.Image.Image image mode=RGB size=887x528 at 0x1A8D7FDB9C8>
